# %% [markdown]
# # <a href="https://miptstats.github.io/courses/ad_mipt.html">Phystech@DataScience</a>
# ## Домашнее задание 6
#
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_pds_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате `ipynb`.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * **Код из рассказанных на занятиях ноутбуков можно использовать без ограничений.**
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив,
#     * отправив ее как файл боту вместе с ноутбуком *или*
#     * вставив ее в ноутбук посредством `Edit -> Insert Image` (<font color="red">фото, вставленные ссылкой, не принимаются</font>);
#   * в виде $LaTeX$ в markdown-ячейках.
# * Решения не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта (вставки фото в ноутбук). <font color="red"><b>Неправильно вставленные фотографии могут не передаться при отправке.</b></font> Для проверки попробуйте переместить `ipynb` в другую папку и открыть его там.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 15 баллов
# * Задача 2 &mdash; 20 баллов
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 3 &mdash; 25 баллов
# * Задача 4 &mdash; 30 баллов
#
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 5 &mdash;  20 баллов
# * Задача 6 &mdash;  15 баллов
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 7 &mdash;  30 баллов
#
#
#
#
# -----

# %%
# Bot check

# HW_ID: phds_hw6
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %% [markdown]
# # Теоретическая часть
#
# ### <b><font color="blue">Легкая часть</font></b>
#
#
# ## Задача 1.
#
# Пусть $X_1,...,X_n$ выборка из некоторого распределения $\mathrm{P}$, причем ${\sf D} X_1=\sigma^2<+\infty$, и $\sigma$ неизвестно.
# Рассмотрим статистику $S^2=\frac1n\sum\limits_{i=1}^n(X_i-\overline{X})^2$.
#
# 1. Докажите, что статистика $S^2$ равна $\overline{X^2}-\overline{X}^2$.
#
# $S^2=\frac1n\sum\limits_{i=1}^n(X_i-\overline{X})^2 = \frac{1}{n} \sum\limits_{i=1}^n (X_i^2 - 2 X_i \overline{X} + \overline{X}^2) = \frac{1}{n} \sum\limits_{i=1}^n X_i^2 - 2\overline{X}\frac{1}{n} \sum\limits_{i=1}^n X_i + \overline{X}^2 = $
# $ = \frac{1}{n} \sum\limits_{i=1}^n X_i^2 - 2\overline{X}^2 + \overline{X}^2 = \frac{1}{n} \sum\limits_{i=1}^n X_i^2 - \overline{X}^2 = \overline{X^2}-\overline{X}^2$
#
#
# 2. Является ли она состоятельной оценкой $\sigma^2$? Для ответа на этот вопрос воспользуйтесь утверждениями с лекции.
#
# **Определение:** Оценка $\widehat{\theta}_n(X_1, ..., X_n)$ называется состоятельной оценкой $\tau(\theta)$, если $\widehat{\theta}_n(X_1, ..., X_n) \xrightarrow[n \to \infty]{P_\theta} \tau(\theta), \forall \theta \in \Theta$
#
# Из ЗБЧ следует, что $\overline{X}$ сходится по вероятности к $E(X)$, а $\overline{X^2}$ к $E(X^2)$. Тогда:
#
# $\displaystyle{\lim_{n \to \infty}} S^2 = \displaystyle{\lim_{n \to \infty}} (\overline{X^2}-\overline{X}^2) \xrightarrow[n \to \infty]{P_\theta} \displaystyle{\lim_{n \to \infty}} (E(X^2)-(E(X))^2) = Var(X) = \sigma^2$ - состоятельная оценка.
#
# 3. Является ли статистика $S^2$ несмещенной оценкой $\sigma^2$? Для ответа на этот вопрос вспомните различные варианты определения дисперсии.
#
# **Определение:** Оценка $\widehat{\theta}(X)$ называется несмещенной оценкой величины $\tau(\theta)$, если $E_\theta (\widehat{\theta}(X)) = \tau(\theta), \forall \theta \in \Theta$.
#
# Не знаю насколько подробно это нужно доказывать, но на лекциях господина Райгородского было следующее:
#
# ![photo_2024-03-16_00-40-18.jpg](data:image/jpeg;base64,...)
#
# Т.о. $S^2=\frac{1}{n - 1}\sum\limits_{i=1}^n(X_i-\overline{X})^2$ - несмещенная оценка $\sigma^2$. В исходной же формулировке оценка является смещенной.

# %% [markdown]
# ## Задача 2.
#
# Пусть $X_1,...,X_n$ выборка из из распределения $\mathcal{N}(\theta, \sigma^2)$, где оба параметра неизвестны.
#
# 1. Предложите несмещенную, сильно состоятельную, асимптотически нормальную оценку $\theta$.
#
# Пусть $\widehat{\theta}(X) = \overline{X} = \frac{1}{n}\sum\limits_{i=1}^nX_i$. Тогда:
# *   $E(\widehat{\theta}_n) = \theta$ - было доказано на лекции. Т.о. оценка - несмещенная.
# *   По ЗБЧ выборочное среднее $\overline{X}$ сходится по вероятности к $\theta$ при $n \rightarrow \infty$, поэтому данная оценка явлется сильно состоятельной.
# *   То что оценка является асимптотически нормальной, следует из ЦПТ, т.е. при достаточно больших n распределение выборочного среднего $\overline{X}$ будет приближаться к нормальному с праметрами $\theta$ и $\sigma^2 / n$.
#
# 2. Постройте асимптотический доверительный интервал для $\theta$ уровня доверия $\alpha$. Можете ли вы использовать полученную формулу, если не знаете $\sigma$?
#
# Т.к. $\sigma$ нам не изветсно, то мы можем использовать состоятельную оценку для стандартной ошибки выборочного среднего $\overline{X}$. Т.к. оценка $\widehat{\theta} = \overline{X}$ является АНО, то стандартная ошибка оценки $\widehat{\theta}$ будет сходится к стандартной ошибке выборочного среднего $\overline{X}$ при $n \rightarrow \infty$.
#
# Стандартная ошибка выборочного среднего вычисляется как $\sigma / \sqrt{n}$ и, т.к. мы не знаем $\sigma$, то мы можем заменить его состоятельной оценкой S -  оценкой выборочного стандартного отклонения. Т.е. стандартная ошибка оценки $\widehat{\theta}$ будет равна $S / \sqrt{n}$.
#
# Для построения АДИ уровня доверия $\alpha$, мы можем использовать квантили стандартного нормального распределения $Z_{\alpha/2}$. Т.к. оценка $\widehat{\theta}$ является асимптотически нормальной, то доверительный интервал можно построить следующим образом:
#
# $\overline{X} - Z_{\alpha/2}\frac{S}{\sqrt{n}}< \theta < \overline{X} + Z_{\alpha/2}\frac{S}{\sqrt{n}}$
#
# *Указание.* Посмотрите пример с занятия.

# %% [markdown]
# ### <b><font color="orange">Сложная часть</font></b>
#
# ## Задача 3.
# Пусть $X_1,...,X_n$ выборка из из распределения $U(0, \theta)$.
#
# 1. Проверьте на несмещенность следующие оценки параметра $\theta$: $2\overline{X}$, $X_{(n)}$, $\frac{n+1}{n}X_{(n)}$.
#
# *Указание.* Найдите функцию распределения случайной величины $X_{(n)}$, посчитав вероятность того, что максимальное значение среди элементов выборки не превосходит числа $x$. Используйте при этом определение выборки. После чего получите плотность $X_{(n)}$.
#
# *   $E(\overline{2X}) = \frac{2}{n} \sum\limits_{i=1}^n E(X_i) = \frac2n \cdot \frac{n\theta}{2} = \theta$ - несмещенная оценка
#
# *   $F_{X_{(n)}} = P(X_{(n)} \leq x) = P(X_1 \leq x; ....; X_{(n)} \leq x) = \left(\frac{x}{\theta}\right)^n$, т.к. $X_i$ - независимы и $P(X \leq x) = \frac{x}{\theta}$.
#
# *   Тогда плотность распределения равна: $f_{X_{(n)}}(x) = n \cdot \left(\frac{x}{\theta}\right)^{n - 1} \cdot \frac{1}{\theta} = \frac{n}{\theta} \cdot \left(\frac{x}{\theta}\right)^{n - 1}$.
#
# *   $E(X_{(n)}) = \int\limits_0^\theta x \cdot \frac{n}{\theta} \cdot \left(\frac{x}{\theta}\right)^{n - 1} dx = \frac{n \theta^{n + 1}}{(n + 1) \theta^n} = \frac{n \theta}{n + 1}$ - не является несмещенной оценкой.
#
# *   $E(\frac{n + 1}{n} X_{(n)}) = \frac{n + 1}{n} E(X_{(n)}) = \frac{n + 1}{n} \cdot \frac{n \theta}{n + 1} = \theta$ - несмещенная оценка.
#
# 2. Проверьте, является ли оценка $2\overline{X}$ состоятельной, сильно состоятельной и асимптотически нормальной.
#
# *   Применим нер-во Колмогорова: $P(|2x - \theta| > \varepsilon) = P\left(|x - \theta| > \frac{\varepsilon}{2}\right) \leq \frac{2D(x)}{n\varepsilon^2} \xrightarrow[n \to \infty]{} 0$. Т.о. $2\overline{X}$ - сильно состоятельная.
#
# *   $\sqrt{n}(2\overline{X} - \theta) = \frac{\sum\limits_{i = 1}^n 2X_i - nE(2X_1)}{\sqrt{n}} \rightarrow N(0, D(2X_1)) = N(0, 4D(X_1))$ - АНО.
#
# 3. Постройте асимптотический доверительный интервал для $\theta$ уровня доверия $\alpha$.
#
# Аналогично предыдщей задаче АДИ будет иметь вид:
#
# $2\overline{X} - Z_{\alpha/2}\frac{\sigma}{\sqrt{n}}< \theta < 2\overline{X} + Z_{\alpha/2}\frac{\sigma}{\sqrt{n}}$, где $\sigma = \frac{\theta^2}{3}$
#
# *Указание.* Посмотрите пример с занятия.

# %% [markdown]
# ## Задача 4
#
# Рассмотрим модель линейной регрессии
#
# $$Y = X \theta + ɛ,$$
#
# где $Y \in \mathbb{R}^n$ - отклик, $X \in \mathbb{R}^{n \times d}$, $\theta \in \mathbb{R}^d$, $ɛ \in \mathbb{R}^n$ - шум, $n > d$, $rk X = d$.
#
# 1. Опишите, какие величины в модели являются
#   - случайными: **отклик Y и шум $\varepsilon$**
#   - неизвестными: **параметр $\theta$**
# 2. Покажите, что если $E ɛ = 0$, то МНК-оценка $\widehat{\theta}$ параметра $\theta$
#
#   $$\widehat{\theta} = (X^TX)^{-1}X^T Y$$
#
#   является несмещенной оценкой параметра $\theta$. Будет ли выполнено свойство несмещенности для Ridge-регрессии?
#
#   *Указание:* используйте свойство линейности математического ожидания в матричном виде.
#
#   *   $\widehat{\theta} = (X^TX)^{-1}X^TY, \; E(\varepsilon) = 0$
#
#   $E(\widehat{\theta}) = E((X^TX)^{-1}X^TY) = E((X^TX)^{-1}X^T(X\theta + \varepsilon)) = E((X^TX)^{-1}X^TX\theta + (X^TX)^{-1}X^T\varepsilon) = $
#
#   $ = \theta + ((X^TX^{-1})X^TE(\varepsilon)) = \theta$ - несмещенная оценка.
#
#   Для Ridge регрессии оценка не будет являться несмещенной, т.к. в выражении для $\widehat{\theta}$ присутсвует матрица ковариаций (дополнительное слагаемое).
#
# 3. Покажите, что, если дополнительно матрица ковариаций $D ɛ = σ^2 I_n$, то дисперсия МНК-оценки: $$D \widehat{\theta} = \sigma^2 (X^TX)^{-1}$$ Что показывает данный результат в случае мультиколлинеарности признаков?
#
# $D(\widehat{\theta}) = D((X^TX)^{-1}X^TY) = D((X^TX)^{-1}X^T(X\theta + \varepsilon)) = D((X^TX)^{-1}X^TX\theta) + D((X^TX)^{-1}X^T\varepsilon) = (X^TX)^{-1} \cdot X^TX \cdot D(\theta) \cdot X^TX \cdot (X^TX)^{-1} + (X^TX)^{-1} \cdot X^T \cdot D(\varepsilon) \cdot X \cdot (X^TX)^{-1} = (X^TX)^{-1} \cdot X^T \cdot \sigma^2I_n \cdot X \cdot (X^TX)^{-1} = \sigma^2(X^TX^{-1})$
#
# Данный результат показывает, что при мультиколлинеарности признаков дисперсия МНК-оценки параметра $\theta$ становится значительно больше, т.к. обратная матрица $(X^TX)^{-1}$ становится более плохо обусловленной при мультиколлинеарности, что приводит к увеличению дисперсии оценки.
#
#   *Указание:* используйте свойство дисперсии в матричном виде.
#
# **Напоминание**
#
# 1. Матричное свойство математического ожидания:
#
#   $∀ A \in \mathbb{R}^{m \times k}$, случайного вектора $\psi \in \mathbb{R}^k$
#
#   $$E A \psi = A E \psi$$
# 2. Матричное свойство дисперсии:
#   $∀ A \in \mathbb{R}^{m \times k}$, случайного вектора $\psi \in \mathbb{R}^k$
#
#   $$D A \psi = A (D \psi) A^T$$

# %% [markdown]
# ---
#
# # Практическая часть

# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D
import scipy.stats as sps

sns.set(font_scale=1.5, palette='Set2')

# %% [markdown]
# ### <b><font color="blue">Легкая часть</font></b>

# %% [markdown]
# ## Задача 5
#
#
# Пусть $X_1, ..., X_n$ &mdash; выборка из распределения $\mathcal{N}(0, \sigma^2)$. Известно, что в качестве оценки параметра $\sigma^2$ можно использовать следующие оценки $S^2, \frac{n}{n-1}S^2$. Проверьте эти оценки на несмещенность повторив эксперимент с семинара.

# %% [markdown]
# Реализуйте две функции, каждая из которых на вход берет несколько выборок, а на выход выдает массив оценок
# (первая функция - $S^2$, вторая функция - $\frac{n}{n-1}S^2$)  для каждой выборки.
# *Примечание:* У матрицы, заданной в виде `numpy.array` есть метод `var` вычисляющий выборочную дисперсию.

# %%
def estimate_s2(X):
    '''
    Принимает на вход массив размером (n_samples, sample_size), выдает массив оценок размера (n_samples,)
    '''
    return np.var(X, axis = 1)

def estimate_s2_corrected(X):
    '''
    Принимает на вход массив размером (n_samples, sample_size), выдает массив оценок размера (n_samples,)
    '''
    n_samples, sample_size = X.shape
    return np.var(X, axis = 1) * (sample_size / (sample_size - 1))

# %% [markdown]
# Проверьте правильность своей реализации

# %%
X = np.array([[1, 3, 3, 6], [2, 5, 1, 89]])
estimate_s2(X)

assert(sum(estimate_s2(X) != np.array([3.1875, 1399.6875])) == 0)
assert(sum(estimate_s2_corrected(X) != np.array((4.25, 1866.25))) == 0)

# %% [markdown]
# Задайте список оценок и разные параметры для отрисовки графика

# %%
estimators = [
    (estimate_s2, r'$S^2$', 'purple', 0.1),
    (estimate_s2_corrected, r'$\frac{n}{n-1}S^2$', 'green', 0.2)
]

# %% [markdown]
# Создайте 500 выборок размера `sample_size`.

# %%
sample_count = 500
sample_size = 100
X = np.array([np.random.normal(0, 1, size = (sample_size,)) for _ in range(sample_count)])
X.shape
# Out:
# (500, 100)

# %% [markdown]
# Визуализируйте полученные оценки на одном графике. Средние значения по 500 экспериментам для каждой оценки нужно обозначить звездочками.

# %%
plt.figure(figsize=(15, 0.7 * len(estimators)))

for estimator, name, color, y in estimators:
    E = estimator(X)
    plt.scatter(E, np.zeros(sample_count) + y, alpha=0.1,
                s=100, color=color, label=name)
    plt.scatter(E.mean(), y, marker='*', s=300,
                color='w', edgecolors='black')

    plt.vlines(1, -1, 1, color='r')
    plt.title('Размер выборки = %d' % sample_size)
    plt.yticks([])
    plt.legend()
    plt.xlim((0.8, 1.2))
    plt.ylim((-0.1, 0.2 * len(estimators)))

plt.show()

# %% [markdown]
# Напишите функцию построения таких графиков в общем виде: на вход функция может получать любые распределения (`distributions`) и любые оценки (`estimators`).

# %%
def est_plot(distribution, estimators, sample_size, sample_count):
    '''
    Построение графика разброса реализаций оценок и их средних значений.

    distribution -- распределение формата scipy.stats
    estimators -- список оценок и параметров для отрисовки графиков
    sample_size -- размер выборок
    sample_count -- количество генерируемых выборок
    '''
    X = distribution.rvs(size=(sample_count, sample_size))

    plt.figure(figsize=(15, 0.7 * len(estimators)))

    for estimator, name, color, y in estimators:
        E = estimator(X)
        plt.scatter(E, np.zeros(sample_count) + y, alpha=0.1, s=100, color=color, label=name)
        plt.scatter(E.mean(), y, marker='*', s=300, color='w', edgecolors='black')

        plt.vlines(1, -1, 1, color='r')
        plt.title('Размер выборки = %d' % sample_size)
        plt.yticks([])
        plt.legend()
        plt.xlim((0.8, 1.2))
        plt.ylim((-0.1, 0.2 * len(estimators)))

    plt.show()

# %% [markdown]
# Постройте три графика, аналогичных верхнему, для разных размеров выборок (10, 100, 500).

# %%
sample_size_list = (10, 100, 500)  # размеры выборок
sample_count = 500  # количество экспериментов

for sample_size in sample_size_list:
    distribution = sps.norm
    est_plot(distribution, estimators, sample_size, sample_count)

# %% [markdown]
# Изучите поведение среднего оценок из первого пункта при росте размера $n$ выборки - постройте график зависимости среднего оценки по всем экспериментам от размера выборки. Для вычисления зависимости нужно один раз сгенерировать выборки из достаточно большого размера и посчитать оценки по префиксам, используя функции из `numpy`.

# %%
def mean_plot(distribution, estimators, n_grid, sample_count):
    '''
    distribution -- распределение формата scipy.stats
    estimators -- список оценок и параметров для отрисовки графиков
    n_grid -- массив значений размера выборки
    sample_count -- количество генерируемых выборок
    '''
    plt.figure(figsize = (20, 5))
    X = distribution.rvs(size = (sample_count, 300))

    for size in n_grid:
        plt.scatter(int(size), estimators[0][0](X[:, :int(size)]).mean(), color = 'blue', s = 10)
        plt.scatter(int(size), estimators[1][0](X[:, :int(size)]).mean(), color='red', s = 10)

    plt.xlabel('Размер выборки')
    plt.ylabel('Среднее значение оценки')
    plt.legend ((r'$S^2$', r'$\frac{n}{n-1}S^2$'))

# %%
n_grid = np.linspace(10, 400, 100)
mean_plot(sps.norm, estimators, n_grid, sample_count)

# %% [markdown]
#  Какие из оценок являются асимптотически несмещёнными (т.е. $\forall \theta \in \Theta\colon \mathsf{E}_\theta \widehat{\theta} \to \theta$ при $n\to +\infty$)?

# %% [markdown]
# **Ответ:** Оценку $\frac{n}{n-1}S^2$ можно считать несмещенной, т.к. ее среднее значение равно истинному параметру, который она оценивает. В то же время оценка $S^2$ является асимптотически несмещенной, так как при небольших размерах выборки может наблюдаться значительное смещение относительно истинного параметра, однако по мере увеличения размера выборки это смещение уменьшается.

# %% [markdown]
# ## Задача 6.
#
# Пусть $X_1, \ldots, X_n$ &mdash; выборка из распределения $\mathcal{N}(a, \sigma^2)$. Визуализируйте свойства состоятельности и асимптотической нормальности для оценки $S^2$ дисперсии $\sigma^2$.

# %% [markdown]
# Зададим параметры эксперимента

# %%
a = 0  # истинное значение параметра
sigma = 1
sample_size = 300  # размер выборок
sample_count = 500  # количество выборок
n_range = (np.arange(sample_size) + 1)  # размеры подвыборок

# %% [markdown]
# Сгенерируем множество выборок из распределения $\mathcal{N}(a, \sigma^2)$ (количество выборок - `sample_count`, размер каждой выборки - `sample_size`)

# %%
# генерируем множество выборок
samples = sps.norm.rvs(size = (sample_count, sample_size))

# %% [markdown]
# Вычислим оценки в зависимости от размера выборки, усредняем по последней оси

# %%
estimation = np.cumsum((samples - np.mean(samples, axis = 1, keepdims = True))**2, axis = 1) / np.arange(1, samples.shape[1] + 1)

# %% [markdown]
# Визуализируем для каждой выборки все оценки в зависимости от размера выборки.

# %%
def est_plot(estimation, sample_count, sample_size, left=None, right=None, xlim = sample_size):
    '''
    estimation -- массив оценок от размера выборки
    sample_count -- количество генерируемых выборок
    sample_size -- размер каждой выборки
    left, rigth -- границы доверительного интеравала, нужны будут далее
    xlim = область по x
    '''
    plt.figure(figsize=(15, 7))
    for i in range(sample_count):
        plt.plot(np.arange(sample_size) + 1, estimation[i], color='blue', alpha=0.05)
    if type(left) and type(right) is np.ndarray:

        plt.plot(np.arange(sample_size) + 1, left, color='black')
        plt.plot(np.arange(sample_size) + 1, right, color='black')
        labels = [r'$\hat{\theta}$', r'$\theta$',
                  'Границы доверительного интервала']
        handels = [Line2D([0], [0], color='blue', lw=2),
                   Line2D([0], [0], color='red', lw=2),
                   Line2D([0], [0], color='black', lw=2)]

    else:
        labels = [r'$\hat{\theta}$', r'$\theta$']
        handels = [Line2D([0], [0], color='blue', lw=2),
                   Line2D([0], [0], color='red', lw=2),]

    plt.hlines(sigma, 0 ,sample_size, color='red')

    plt.title('Поведение оценки для разных реализаций')
    plt.xlabel('Размер выборки')
    plt.ylim((0, 5))
    plt.legend(handels, labels)
    plt.xlim((0, xlim));

# %%
est_plot(estimation, sample_count, sample_size)

# %% [markdown]
# Добавим доверительный интервал для нашей оценки.

# %%
right = sigma + 2 * sigma / np.sqrt(n_range)
left = sigma - 2 * sigma / np.sqrt(n_range)

est_plot(estimation, sample_count, sample_size, left = left, right = right)

# %% [markdown]
# Приблизим этот график в области малых размеров выборки (до 50).

# %%
est_plot(estimation, sample_count, sample_size, left = left, right = right, xlim = 50)

# %% [markdown]
# ## Задача 7
#
# В данной задаче нужно проверить на несмещенность МНК-оценку в линейной регрессии и оценку в Ridge-регрессии.
#
# 1. При заданных $X, Y, \lambda$ выпишите формулы для
#   - Решения задачи МНК **$\widehat{\theta}_{МНК} = (X^TX)^{-1}X^TY$**
#   - Решения задачи Ridge-регрессии **$\widehat{\theta}_{Ridge} = (X^TX + \lambda I)^{-1}X^TY$**
# 2. Визуализируйте, являюся ли данные оценки несмещенными аналогично задаче 5. Для этого нужно во многих экспериментах посчитать реализации оценок $\widehat{\theta}_{МНК}$, $\widehat{\theta}_{Ridge}$ и нанести их на график.
#   - Учитывая ответы в задаче 4, опишите, как должны генерироваться выборки для визуализации. Какие величины в формулах из п.1 должны быть зафиксированы? Какие должны меняться от эксперимента к эксперименту? Каким образом?
#
#     *  **Зафиксированные величины:**
#         *   Значения признаков $X$ (матрица признаков) должны быть фиксированными для каждого эксперимента.
#         *   Истинное значение параметра $\theta$ должно быть задано.
#     *   **Меняющиеся величины:**
#         *    Отклик $Y$ будет меняться от эксперимента к эксперименту в результате добавления шума.
#         *    Параметр $\lambda$ в Ridge-регрессии может быть задан различными значениями.
#
#   - Задайте сами истинное значение $\theta$ и значения признаков $X \in \mathcal{R}^{n \times d}$. Учитывайте, что для выполнения условия теоремы с лекции $n > d$ и $rk X = d$. Для Ridge-регрессии возьмите два значения $\lambda$. Сгенерируйте зашумленные значения $Y$, с помощью которых можно получить выборки для каждого вида оценки. Визуализируйте их аналогично задаче 5. Распределение шума $ɛ$ можно считать нормальным.
#
#   **Внимание:** вы должны получить $n$ реализаций $Y$, по которым будут посчитаны $n$ реализаций оценок каждого вида.

# %% [markdown]
# Определим функции для оценок МНК и Ridge-регрессии

# %%
def estimate_MNK(X, Y):
    return np.linalg.inv(X.T @ X) @ X.T @ Y

def estimate_Ridge(X, Y, lambda_val):
    d = X.shape[1]
    return np.linalg.inv(X.T @ X + lambda_val * np.eye(d)) @ X.T @ Y

# %% [markdown]
# Определим список оценок и параметров для отрисовки графиков

# %%
estimators = [
    (estimate_MNK, r'$\hat{\theta}_{\text{МНК}}$', 'purple', 0),
    (estimate_Ridge, r'$\hat{\theta}_{\text{Ridge}}$', 'green', 0.1),
]

# %% [markdown]
# Дальше сделать не успел :(
